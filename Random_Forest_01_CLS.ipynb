# %%
import pandas as pd,numpy as np,matplotlib.pyplot as plt,seaborn as sns

# %%
df=pd.read_csv("online_sales_dataset.csv")

# %%
df
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49782 entries, 0 to 49781
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceNo          49782 non-null  int64
#  1   StockCode          49782 non-null  object
#  2   Description        49782 non-null  object
#  3   Quantity           49782 non-null  int64
#  4   InvoiceDate        49782 non-null  object
#  5   UnitPrice          49782 non-null  float64
#  6   CustomerID         44804 non-null  float64
#  7   Country            49782 non-null  object
#  8   Discount           49782 non-null  float64
#  9   PaymentMethod      49782 non-null  object
#  10  ShippingCost       47293 non-null  float64
#  11  Category           49782 non-null  object
#  12  SalesChannel       49782 non-null  object
#  13  ReturnStatus       49782 non-null  object
#  14  ShipmentProvider   49782 non-null  object
#  15  WarehouseLocation  46297 non-null  object
# ...

# %%
df.shape
# Out:
# (49782, 17)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'Discount', 'PaymentMethod',
#        'ShippingCost', 'Category', 'SalesChannel', 'ReturnStatus',
#        'ShipmentProvider', 'WarehouseLocation', 'OrderPriority'],
#       dtype='object')

# %%
df.drop(columns={"InvoiceNo","CustomerID","PaymentMethod","SalesChannel","InvoiceDate","ReturnStatus","Quantity"},inplace=True)

# %%
df
# Out:
#       StockCode   Description  UnitPrice         Country  Discount  \
# 0      SKU_1964     White Mug       1.71       Australia  0.470000
# 1      SKU_1241     White Mug      41.25           Spain  0.190000
# 2      SKU_1501    Headphones      29.11         Germany  0.350000
# 3      SKU_1760     Desk Lamp      76.68     Netherlands  0.140000
# 4      SKU_1386     USB Cable     -68.11  United Kingdom  1.501433
# ...         ...           ...        ...             ...       ...
# 49777  SKU_1562      Blue Pen      70.92           Spain  0.200000
# 49778  SKU_1930     USB Cable      51.74   United States  0.230000
# 49779  SKU_1766  Office Chair      85.25        Portugal  0.200000
# 49780  SKU_1602      Notebook      39.64  United Kingdom  0.310000
# 49781  SKU_1832     White Mug      38.27          France  0.100000
#
#        ShippingCost     Category ShipmentProvider WarehouseLocation  \
# 0             10.79      Apparel              UPS            London
# ...

# %%
df.isnull().sum()
# Out:
# StockCode               0
# Description             0
# UnitPrice               0
# Country                 0
# Discount                0
# ShippingCost         2489
# Category                0
# ShipmentProvider        0
# WarehouseLocation    3485
# OrderPriority           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49782 entries, 0 to 49781
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StockCode          49782 non-null  object
#  1   Description        49782 non-null  object
#  2   UnitPrice          49782 non-null  float64
#  3   Country            49782 non-null  object
#  4   Discount           49782 non-null  float64
#  5   ShippingCost       47293 non-null  float64
#  6   Category           49782 non-null  object
#  7   ShipmentProvider   49782 non-null  object
#  8   WarehouseLocation  46297 non-null  object
#  9   OrderPriority      49782 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 3.8+ MB

# %%
for i in df.columns:
    if df[i].dtype=="object":
        print(i)
# Out:
# StockCode
# Description
# Country
# Category
# ShipmentProvider
# WarehouseLocation
# OrderPriority

# %%
df.dropna(inplace=True)

# %%
from sklearn import preprocessing

# %%
encode=preprocessing.LabelEncoder()

# %%
# for i in df.columns:
#     if df[i].dtype=="object":

# %%
df
# Out:
#       StockCode   Description  UnitPrice         Country  Discount  \
# 0      SKU_1964     White Mug       1.71       Australia      0.47
# 1      SKU_1241     White Mug      41.25           Spain      0.19
# 2      SKU_1501    Headphones      29.11         Germany      0.35
# 3      SKU_1760     Desk Lamp      76.68     Netherlands      0.14
# 5      SKU_1006  Office Chair      70.16          Sweden      0.48
# ...         ...           ...        ...             ...       ...
# 49777  SKU_1562      Blue Pen      70.92           Spain      0.20
# 49778  SKU_1930     USB Cable      51.74   United States      0.23
# 49779  SKU_1766  Office Chair      85.25        Portugal      0.20
# 49780  SKU_1602      Notebook      39.64  United Kingdom      0.31
# 49781  SKU_1832     White Mug      38.27          France      0.10
#
#        ShippingCost     Category ShipmentProvider WarehouseLocation  \
# 0             10.79      Apparel              UPS            London
# ...

# %%
df.isnull().sum()
# Out:
# StockCode            0
# Description          0
# UnitPrice            0
# Country              0
# Discount             0
# ShippingCost         0
# Category             0
# ShipmentProvider     0
# WarehouseLocation    0
# OrderPriority        0
# dtype: int64

# %%
df['UnitPrice'].unique()
# Out:
# array([ 1.71, 41.25, 29.11, ..., 74.3 , 64.17, 57.59])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df['UnitPrice']=scaler.fit_transform(df[['UnitPrice']])

# %%
df['UnitPrice'].nunique()
# Out:
# 9788

# %%
df
# Out:
#       StockCode   Description  UnitPrice         Country  Discount  \
# 0      SKU_1964     White Mug  -1.710127       Australia      0.47
# 1      SKU_1241     White Mug  -0.327086           Spain      0.19
# 2      SKU_1501    Headphones  -0.751723         Germany      0.35
# 3      SKU_1760     Desk Lamp   0.912194     Netherlands      0.14
# 5      SKU_1006  Office Chair   0.684135          Sweden      0.48
# ...         ...           ...        ...             ...       ...
# 49777  SKU_1562      Blue Pen   0.710719           Spain      0.20
# 49778  SKU_1930     USB Cable   0.039836   United States      0.23
# 49779  SKU_1766  Office Chair   1.211958        Portugal      0.20
# 49780  SKU_1602      Notebook  -0.383401  United Kingdom      0.31
# 49781  SKU_1832     White Mug  -0.431322          France      0.10
#
#        ShippingCost     Category ShipmentProvider WarehouseLocation  \
# 0             10.79      Apparel              UPS            London
# ...

# %%
for i in df.columns:
    if df[i].dtype!="object":
            plt.boxplot(df[i])
            print(i)
            plt.show()
# Out:
# UnitPrice
# Discount
# ShippingCost

# %%
x=df.iloc[:,0:-1]
x
# Out:
#       StockCode   Description  UnitPrice         Country  Discount  \
# 0      SKU_1964     White Mug  -1.710127       Australia      0.47
# 1      SKU_1241     White Mug  -0.327086           Spain      0.19
# 2      SKU_1501    Headphones  -0.751723         Germany      0.35
# 3      SKU_1760     Desk Lamp   0.912194     Netherlands      0.14
# 5      SKU_1006  Office Chair   0.684135          Sweden      0.48
# ...         ...           ...        ...             ...       ...
# 49777  SKU_1562      Blue Pen   0.710719           Spain      0.20
# 49778  SKU_1930     USB Cable   0.039836   United States      0.23
# 49779  SKU_1766  Office Chair   1.211958        Portugal      0.20
# 49780  SKU_1602      Notebook  -0.383401  United Kingdom      0.31
# 49781  SKU_1832     White Mug  -0.431322          France      0.10
#
#        ShippingCost     Category ShipmentProvider WarehouseLocation
# 0             10.79      Apparel              UPS            London
# ...

# %%
x.ndim
# Out:
# 2

# %%
corr=x.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 corr=x.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
sns.heatmap(corr,annot=True)
plt.figure(figsize=(10,40))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 sns.heatmap(corr,annot=True)
#       2 plt.figure(figsize=(10,40))
#
# NameError: name 'corr' is not defined

# %%
y=df["OrderPriority"]

# %%
y.ndim
# Out:
# 1

# %%
y.shape
# Out:
# (46297,)

# %%
for i in x.columns:
    if df[i].dtype=="object":
         x[i]=encode.fit_transform(x[i])

# %%
y
# Out:
# 0        Medium
# 1        Medium
# 2          High
# 3           Low
# 5        Medium
#           ...
# 49777    Medium
# 49778       Low
# 49779      High
# 49780    Medium
# 49781       Low
# Name: OrderPriority, Length: 46297, dtype: object

# %%
x
# Out:
#        StockCode  Description  UnitPrice  Country  Discount  ShippingCost  \
# 0            964            9  -1.710127        0      0.47         10.79
# 1            241            9  -0.327086        8      0.19          9.51
# 2            501            3  -0.751723        3      0.35         23.03
# 3            760            2   0.912194        5      0.14         11.08
# 5              6            5   0.684135        9      0.48         13.98
# ...          ...          ...        ...      ...       ...           ...
# 49777        562            1   0.710719        8      0.20          8.96
# 49778        930            7   0.039836       11      0.23         23.55
# 49779        766            5   1.211958        7      0.20         16.26
# 49780        602            4  -0.383401       10      0.31         28.56
# 49781        832            9  -0.431322        2      0.10          9.13
#
#        Category  ShipmentProvider  WarehouseLocation
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,shuffle=True,test_size = 0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rf = RandomForestClassifier(bootstrap=True,criterion='gini',n_estimators=50)

# %%
Rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
y_pred = Rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)*100
# Out:
# 33.96688264938805

# %%
df

# %%
from sklearn.linear_model import LogisticRegression

# %%
regressor = LogisticRegression()

# %%
regressor.fit(x_train,y_train)

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)*100

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Dt = DecisionTreeClassifier(criterion="entropy")

# %%
Dt.fit(x_train,y_train)

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)*100
